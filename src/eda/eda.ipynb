# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/dkeate/.netrc.
# wandb: Currently logged in as: dkeate (dkeate-western-governors-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/dkeate/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20260711_132655-1red2ghn</code>
# Syncing run <strong><a href='https://wandb.ai/dkeate-western-governors-university/nyc_airbnb/runs/1red2ghn' target="_blank">blooming-eon-1</a></strong> to <a href='https://wandb.ai/dkeate-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dkeate-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/dkeate-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/dkeate-western-governors-university/nyc_airbnb/runs/1red2ghn' target="_blank">https://wandb.ai/dkeate-western-governors-university/nyc_airbnb/runs/1red2ghn</a>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/apis/normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/apis/public/api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/artifacts/artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/artifacts/artifact.py:311, in Artifact._membership_from_name(cls, path, client)
#     310     msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 311     raise ValueError(msg)
#     313 return cls._from_membership(membership, target=path, client=client)
#
# ValueError: artifact membership 'sample.csv:latest' not found in 'dkeate-western-governors-university/nyc_airbnb'
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import wandb
#       2 import pandas as pd
#       3 # Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
#       4 run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
# ----> 5 local_path = wandb.use_artifact("sample.csv:latest").file()
#       6 df = pd.read_csv(local_path)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/wandb_run.py:400, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     397     run_id = self._attach_id
#     399 with wb_logging.log_to_run(run_id):
# --> 400     return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/wandb_run.py:458, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     455 @functools.wraps(func)
#     456 def wrapper_fn(self: Run, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     457     if not getattr(self, "_is_finished", False):
# --> 458         return func(self, *args, **kwargs)
#     460     message = (
#     461         f"Run ({self.id}) is finished. The call to"
#     462         f" `{func.__name__}` will be ignored."
#     463         f" Please make sure that you are using an active run."
#     464     )
#     466     raise UsageError(message)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/wandb_run.py:445, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     442     finally:
#     443         _is_attaching = ""
# --> 445 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/wandb_run.py:3094, in Run.use_artifact(self, artifact_or_name, type, aliases, use_as)
#    3092 name = artifact_or_name
#    3093 public_api = self._public_api()
# -> 3094 artifact = public_api._artifact(type=type, name=name)
#    3095 if type is not None and type != artifact.type:
#    3096     raise ValueError(
#    3097         f"Supplied type {type} does not match type {artifact.type} of artifact {artifact.name}"
#    3098     )
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/apis/normalize.py:82, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      80     raise
#      81 else:
# ---> 82     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/apis/normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      26 message = "Whoa, you found a bug."
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#      31     errors = parse_backend_error_messages(error.response)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/apis/public/api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1489     raise ValueError(
#    1490         "Could not determine entity. Please include the entity as part of the artifact name path."
#    1491     )
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#    1500     raise ValueError(
#    1501         f"type {type} specified but this artifact is of type {artifact.type}"
#    1502     )
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/artifacts/artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     323 from ._generated import ARTIFACT_BY_NAME_GQL, ArtifactByName
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#     334 gql_op = gql(ARTIFACT_BY_NAME_GQL)
#
# File ~/miniconda3/envs/nyc_airbnb_dev/lib/python3.13/site-packages/wandb/sdk/artifacts/artifact.py:311, in Artifact._membership_from_name(cls, path, client)
#     309     entity_project = f"{path.prefix}/{path.project}"
#     310     msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 311     raise ValueError(msg)
#     313 return cls._from_membership(membership, target=path, client=client)
#
# CommError: artifact membership 'sample.csv:latest' not found in 'dkeate-western-governors-university/nyc_airbnb'

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()

# %% [markdown]
# 7. Save the notebook.
